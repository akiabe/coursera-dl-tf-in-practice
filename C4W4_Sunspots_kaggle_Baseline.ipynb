# %% [markdown]
# <a href="https://colab.research.google.com/github/akiabe/coursera-dl-tf-in-practice/blob/master/C4W4_Sunspots_kaggle_Baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
# Define helper function of plotting chart
import numpy as np
import matplotlib.pyplot as plt

def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Access server and download dataset
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/Sunspots.csv \
    -O /tmp/sunspots.csv
# Out:
# --2020-06-13 18:53:39--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/Sunspots.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.68.128, 2404:6800:4003:c03::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.68.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70827 (69K) [application/octet-stream]
# Saving to: ‘/tmp/sunspots.csv’
#
# /tmp/sunspots.csv   100%[===================>]  69.17K  --.-KB/s    in 0s
#
# 2020-06-13 18:53:40 (149 MB/s) - ‘/tmp/sunspots.csv’ saved [70827/70827]

# %%
# Read the csv file and get data into a list of sunspots and timesteps
import csv

time_step = []
sunspots = []

with open('/tmp/sunspots.csv') as csvfile:
  reader = csv.reader(csvfile, delimiter=',')
  # Read the column title and end up throwing it away
  next(reader)
  # Loop through the reader and append data into list
  for row in reader:
    sunspots.append(float(row[2]))
    time_step.append(int(row[0]))
  
  # Convert list into numpy array
  series = np.array(sunspots)
  time = np.array(time_step)

# %%
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Split dataset into training and validation sets
split_time = 3000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

# Set the constans that pass to the windowed_dataset function
window_size = 60
batch_size = 32
shuffle_buffer_size = 1000

# %%
# Define helper function of turning the data into a window dataset
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  # Create dataset from series and pass the series to it
  dataset = tf.data.Dataset.from_tensor_slices(series)
  # Window the dataset
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
  # Mapping a dataset element to a (window_size + 1) batch size dataset
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
  # Shuffle the dataset at the shuffle_buffer and split into features and labels
  dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
  # Batch the select batch size
  dataset = dataset.batch(batch_size).prefetch(1)

  return dataset

# %%
# Set the dataset
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# Buld the convolutional and LSTM-based model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(20, input_shape=[window_size], activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1)   
])

optimizer = tf.keras.optimizers.SGD(lr=1e-7, momentum=0.9)

model.compile(
    loss="mse",
    optimizer=optimizer
)

history = model.fit(
    train_set,
    epochs=100,
    verbose=1
)

print("Training Complete!")
# Out:
# Epoch 1/100
# 92/92 [==============================] - 0s 4ms/step - loss: 3564.5525
# Epoch 2/100
# 92/92 [==============================] - 0s 4ms/step - loss: 592.5928
# Epoch 77/100
# 92/92 [==============================] - 0s 4ms/step - loss: 590.3701
# Epoch 78/100
# 92/92 [==============================] - 0s 4ms/step - loss: 596.6042
# Epoch 79/100
# 92/92 [==============================] - 0s 4ms/step - loss: 589.9194
# Epoch 80/100
# 92/92 [==============================] - 0s 4ms/step - loss: 593.7548
# Epoch 81/100
# 92/92 [==============================] - 0s 4ms/step - loss: 598.7969
# Epoch 82/100
# 92/92 [==============================] - 0s 4ms/step - loss: 593.5843
# Epoch 83/100
# 92/92 [==============================] - 0s 4ms/step - loss: 586.9518
# Epoch 84/100
# 92/92 [==============================] - 0s 4ms/step - loss: 586.0571
# Epoch 85/100
# 92/92 [==============================] - 0s 4ms/step - loss: 591.5333
# Epoch 86/100
# 92/92 [==============================] - 0s 4ms/step - loss: 597.9343
# Epoch 87/100
# 92/92 [==============================] - 0s 4ms/step - loss: 585.1416
# Epoch 88/100
# 92/92 [==============================] - 0s 4ms/step - loss: 585.6019
# Epoch 89/100
# 92/92 [==============================] - 0s 4ms/step - loss: 585.0688
# Epoch 90/100
# 92/92 [==============================] - 0s 4ms/step - loss: 583.1450
# Epoch 91/100
# 92/92 [==============================] - 0s 4ms/step - loss: 589.4059
# Epoch 92/100
# 92/92 [==============================] - 0s 4ms/step - loss: 585.7281
# Epoch 93/100
# 92/92 [==============================] - 0s 4ms/step - loss: 585.5203
# Epoch 94/100
# 92/92 [==============================] - 0s 4ms/step - loss: 583.9581
# Epoch 95/100
# 92/92 [==============================] - 0s 4ms/step - loss: 585.7553
# Epoch 96/100
# 92/92 [==============================] - 0s 4ms/step - loss: 580.1859
# Epoch 97/100
# 92/92 [==============================] - 0s 4ms/step - loss: 581.5559
# Epoch 98/100
# 92/92 [==============================] - 0s 4ms/step - loss: 588.0018
# Epoch 99/100
# 92/92 [==============================] - 0s 4ms/step - loss: 588.4756
# Epoch 100/100
# 92/92 [==============================] - 0s 4ms/step - loss: 585.7433
# Training Complete!

# %%
# Forecast every time points of time series
forecast=[]

# Iterate over the series and taking slice the window size and predict them
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

# Split results after the split time and load them into numpy array
forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]

# Plot results
plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
# Compute mean absolute error and check the size of error
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 14.627637

# %%
# Chage the window_size and retrain the same model
window_size = 30

# Set the dataset
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size
# Epoch 74/100
# 93/93 [==============================] - 0s 4ms/step - loss: 603.5552
# Epoch 75/100
# 93/93 [==============================] - 0s 4ms/step - loss: 603.1755
# Epoch 76/100
# 93/93 [==============================] - 0s 4ms/step - loss: 600.0978
# Epoch 77/100
# 93/93 [==============================] - 0s 4ms/step - loss: 598.8939
# Epoch 78/100
# 93/93 [==============================] - 0s 4ms/step - loss: 602.6367
# Epoch 79/100
# 93/93 [==============================] - 0s 4ms/step - loss: 601.5305
# Epoch 80/100
# 93/93 [==============================] - 0s 4ms/step - loss: 601.9200
# Epoch 81/100
# 93/93 [==============================] - 0s 3ms/step - loss: 602.5579
# Epoch 82/100
# 93/93 [==============================] - 0s 4ms/step - loss: 596.8537
# Epoch 83/100
# 93/93 [==============================] - 0s 4ms/step - loss: 597.6393
# Epoch 84/100
# 93/93 [==============================] - 0s 4ms/step - loss: 599.6347
# Epoch 85/100
# 93/93 [==============================] - 0s 4ms/step - loss: 601.7059
# Epoch 86/100
# 93/93 [==============================] - 0s 4ms/step - loss: 598.5999
# Epoch 87/100
# 93/93 [==============================] - 0s 4ms/step - loss: 595.9033
# Epoch 88/100
# 93/93 [==============================] - 0s 4ms/step - loss: 606.3968
# Epoch 89/100
# 93/93 [==============================] - 0s 4ms/step - loss: 600.0369
# Epoch 90/100
# 93/93 [==============================] - 0s 4ms/step - loss: 595.9199
# Epoch 91/100
# 93/93 [==============================] - 0s 4ms/step - loss: 595.9326
# Epoch 92/100
# 93/93 [==============================] - 0s 4ms/step - loss: 600.0978
# Epoch 93/100
# 93/93 [==============================] - 0s 4ms/step - loss: 609.5306
# Epoch 94/100
# 93/93 [==============================] - 0s 4ms/step - loss: 596.9155
# Epoch 95/100
# 93/93 [==============================] - 0s 4ms/step - loss: 595.5989
# Epoch 96/100
# 93/93 [==============================] - 0s 3ms/step - loss: 599.9628
# Epoch 97/100
# 93/93 [==============================] - 0s 4ms/step - loss: 597.6855
# Epoch 98/100
# 93/93 [==============================] - 0s 3ms/step - loss: 596.9393
# Epoch 99/100
# 93/93 [==============================] - 0s 3ms/step - loss: 596.8950
# Epoch 100/100
# 93/93 [==============================] - 0s 3ms/step - loss: 596.6327
# Training Complete!

# %%
# Forecast every time points of time series
forecast=[]

# Iterate over the series and taking slice the window size and predict them
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

# Split results after the split time and load them into numpy array
forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]

# Plot results
plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
# Compute mean absolute error and check the size of error
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 14.481601

# %%
# Chage the input layer size
window_size = 30

# Set the dataset
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size
# Epoch 72/100
# 93/93 [==============================] - 0s 4ms/step - loss: 596.6584
# Epoch 73/100
# 93/93 [==============================] - 0s 4ms/step - loss: 594.9807
# Epoch 74/100
# 93/93 [==============================] - 0s 4ms/step - loss: 591.7838
# Epoch 75/100
# 93/93 [==============================] - 0s 4ms/step - loss: 600.9147
# Epoch 76/100
# 93/93 [==============================] - 0s 4ms/step - loss: 597.8060
# Epoch 77/100
# 93/93 [==============================] - 0s 4ms/step - loss: 596.6549
# Epoch 78/100
# 93/93 [==============================] - 0s 4ms/step - loss: 592.2030
# Epoch 79/100
# 93/93 [==============================] - 0s 4ms/step - loss: 593.8877
# Epoch 80/100
# 93/93 [==============================] - 0s 4ms/step - loss: 590.8015
# Epoch 81/100
# 93/93 [==============================] - 0s 4ms/step - loss: 589.3779
# Epoch 82/100
# 93/93 [==============================] - 0s 4ms/step - loss: 589.3301
# Epoch 83/100
# 93/93 [==============================] - 0s 4ms/step - loss: 589.8622
# Epoch 84/100
# 93/93 [==============================] - 0s 4ms/step - loss: 590.7028
# Epoch 85/100
# 93/93 [==============================] - 0s 4ms/step - loss: 589.4887
# Epoch 86/100
# 93/93 [==============================] - 0s 3ms/step - loss: 591.0248
# Epoch 87/100
# 93/93 [==============================] - 0s 4ms/step - loss: 589.3315
# Epoch 88/100
# 93/93 [==============================] - 0s 4ms/step - loss: 585.9636
# Epoch 89/100
# 93/93 [==============================] - 0s 4ms/step - loss: 589.3574
# Epoch 90/100
# 93/93 [==============================] - 0s 3ms/step - loss: 587.0009
# Epoch 91/100
# 93/93 [==============================] - 0s 4ms/step - loss: 592.3620
# Epoch 92/100
# 93/93 [==============================] - 0s 4ms/step - loss: 594.8265
# Epoch 93/100
# 93/93 [==============================] - 0s 4ms/step - loss: 589.0824
# Epoch 94/100
# 93/93 [==============================] - 0s 4ms/step - loss: 585.7040
# Epoch 95/100
# 93/93 [==============================] - 0s 4ms/step - loss: 586.2746
# Epoch 96/100
# 93/93 [==============================] - 0s 4ms/step - loss: 589.9857
# Epoch 97/100
# 93/93 [==============================] - 0s 4ms/step - loss: 591.5067
# Epoch 98/100
# 93/93 [==============================] - 0s 4ms/step - loss: 587.3934
# Epoch 99/100
# 93/93 [==============================] - 0s 3ms/step - loss: 584.2876
# Epoch 100/100
# 93/93 [==============================] - 0s 4ms/step - loss: 585.4236
# Training Complete!

# %%
# Forecast every time points of time series
forecast=[]

# Iterate over the series and taking slice the window size and predict them
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

# Split results after the split time and load them into numpy array
forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]

# Plot results
plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
# Compute mean absolute error and check the size of error
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 14.6749

# %%
# Prediction
model.predict(series[3205:3235][np.newaxis])
# Out:
# array([[2.860163]], dtype=float32)
